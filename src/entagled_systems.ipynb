# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

# %%
qc = QuantumCircuit(2)
qc.h(1)
qc.cx(1,0)
qc.x(1)
qc.draw()
# Out:
#           ┌───┐
# q_0: ─────┤ X ├─────
#      ┌───┐└─┬─┘┌───┐
# q_1: ┤ H ├──■──┤ X ├
#      └───┘     └───┘

# %%
q = Statevector(qc)
q
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %%
counts_sv = q.sample_counts(100)
print(counts_sv)
# Out:
# {np.str_('01'): np.int64(58), np.str_('10'): np.int64(42)}

# %%
qc.measure_all()
qc.draw()
# Out:
#              ┌───┐      ░ ┌─┐
#    q_0: ─────┤ X ├──────░─┤M├───
#         ┌───┐└─┬─┘┌───┐ ░ └╥┘┌─┐
#    q_1: ┤ H ├──■──┤ X ├─░──╫─┤M├
#         └───┘     └───┘ ░  ║ └╥┘
# meas: 2/═══════════════════╩══╩═
#                            0  1

# %%
from qiskit.providers.basic_provider import BasicSimulator
sim = BasicSimulator()

# %%
counts_sim = sim.run(qc, shots=100).result().get_counts()
print(counts_sim)
# Out:
# {'01': 49, '10': 51}

# %%
from qiskit.visualization import plot_histogram

# %%
plot_histogram(counts_sim)

# %%
qc = QuantumCircuit(2)
qc.h([0,1])
qc.measure_all()
qc.draw()
# Out:
#         ┌───┐ ░ ┌─┐
#    q_0: ┤ H ├─░─┤M├───
#         ├───┤ ░ └╥┘┌─┐
#    q_1: ┤ H ├─░──╫─┤M├
#         └───┘ ░  ║ └╥┘
# meas: 2/═════════╩══╩═
#                  0  1

# %%
counts_sim = sim.run(qc, shots=100).result().get_counts()
print(counts_sim)
# Out:
# {'00': 27, '11': 23, '10': 23, '01': 27}

# %%
plot_histogram(counts_sim)
