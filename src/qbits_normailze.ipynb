# %%
from numpy import sqrt
from qiskit.quantum_info import Statevector

qa = Statevector.from_label('+')
qb = Statevector.from_label('0')

# %%
qa.inner(qb)
# Out:
# np.complex128(0.7071067811865475+0j)

# %%
qa.inner(qa)
# Out:
# np.complex128(0.9999999999999998+0j)

# %%
qn = Statevector([1/2,1/3])
qn
# Out:
# Statevector([0.5       +0.j, 0.33333333+0.j],
#             dims=(2,))

# %%
qn.is_valid()
# Out:
# False

# %%
qn_len = sqrt(qn.inner(qn))
qn = qn/qn_len

# %%
qn.is_valid()
# Out:
# True
